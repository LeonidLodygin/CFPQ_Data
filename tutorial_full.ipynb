# %% [markdown]
# ## Tutorial
#
# Release
#
# :   4.0.3
#
# Date
#
# :   Jun 05, 2026
#
# This guide can help you start working with CFPQ_Data.
#
# **You can download this tutorial as a Jupyter Notebook from the link at the end of the page.**
#
# ### Import
#
# First you need to import the package.

# %%
import cfpq_data

# %% [markdown]
# # Load graph
#
# After the package is imported, we can load the graphs.
#
# ## Load graph archive from Dataset
#
# We can load the archive with the graph using function `download`.

# %%
bzip_path = cfpq_data.download("bzip")
# Out:
# [2026-06-05 11:05:09]>INFO>Found graph with name='bzip'
# [2026-06-05 11:05:09]>INFO>Load archive graph_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/graphs/bzip.tar.gz')
# [2026-06-05 11:05:09]>INFO>Unzip graph name='bzip' to file graph=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/graphs/bzip/bzip.csv')
# [2026-06-05 11:05:09]>INFO>Remove archive graph_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/graphs/bzip.tar.gz')

# %% [markdown]
# # Load graph by path
#
# We can load the graph along the specified path using function `graph_from_csv`.

# %%
bzip = cfpq_data.graph_from_csv(bzip_path)
# Out:
# [2026-06-05 11:05:09]>INFO>Load graph=<networkx.classes.multidigraph.MultiDiGraph object at 0x7f91adeba250> from path=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/graphs/bzip/bzip.csv')

# %% [markdown]
# Create graph
#
# We can also create a synthetic graph using one of the generators in module Graph generators.
#
# # Create a one cycle graph
#
# For example, let's create a one cycle graph, with 5 nodes, the edges of which are marked with the letter `a`.

# %%
cycle = cfpq_data.labeled_cycle_graph(5, label="a")
# Out:
# [2026-06-05 11:05:09]>INFO>Create a cycle graph=<networkx.classes.multidigraph.MultiDiGraph object at 0x7f91dcacbb10> with n=5, label='a'

# %% [markdown]
# Change edges
#
# We can change the specified graph labels by using function `change_edges`
# from Graph utilities.

# %%
new_cycle = cfpq_data.change_edges(cycle, {"a": "b"})
# Out:
# [2026-06-05 11:05:09]>INFO>Change labels in graph=<networkx.classes.multidigraph.MultiDiGraph object at 0x7f91dcacbb10> with mapping={'a': 'b'} to new_graph=<networkx.classes.multidigraph.MultiDiGraph object at 0x7f91adec8150>

# %% [markdown]
# Now the labels `a` have changed to `b`.
#
# # Add reverse edges
#
# In addition, we can add reverse edges to the graph by using function `add_reverse_edges`
# from Graph utilities. This is extremely useful if graph analysis is formulated using such reverse edges.

# %%
new_cycle_with_reversed = cfpq_data.add_reverse_edges(new_cycle)
# Out:
# [2026-06-05 11:05:09]>INFO>Add reverse edges in graph=<networkx.classes.multidigraph.MultiDiGraph object at 0x7f91adec8150> with mapping=None to new_graph=<networkx.classes.multidigraph.MultiDiGraph object at 0x7f91adf37fd0>

# %% [markdown]
# Now, for each edge with label `a` this graph contains the reversed edge with label `a_r`.
#
# # Load grammar
#
# Also, we can load the grammars generated from grammar templates that are described on the Grammars page.
#
# ## Load grammars archive from Dataset
#
# We can load the archive with the grammars for the specified template using function `download_grammars`.

# %%
c_alias_path = cfpq_data.download_grammars("c_alias")
# Out:
# [2026-06-05 11:05:09]>INFO>Found grammar template='c_alias'
# [2026-06-05 11:05:10]>INFO>Load archive grammar_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/grammars/c_alias.tar.gz')
# [2026-06-05 11:05:10]>INFO>Unzip grammars with template='c_alias' for graph with graph_name=None to directory grammars=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/grammars/c_alias')
# [2026-06-05 11:05:10]>INFO>Remove archive grammar_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/grammars/c_alias.tar.gz')

# %% [markdown]
# # Load grammars archive for specified graph
#
# For some grammar templates we also can load the archive with the grammars for specific graphs.

# %%
java_pt_avrora_path = cfpq_data.download_grammars("java_points_to", graph_name="avrora")
# Out:
# [2026-06-05 11:05:10]>INFO>Found graph with graph_name='avrora' and grammar template='java_points_to'
# [2026-06-05 11:05:10]>INFO>Load archive grammar_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/grammars/java_points_to_avrora.tar.gz')
# [2026-06-05 11:05:10]>INFO>Unzip grammars with template='java_points_to' for graph with graph_name='avrora' to directory grammars=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/grammars/java_points_to_avrora')
# [2026-06-05 11:05:10]>INFO>Remove archive grammar_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/grammars/java_points_to_avrora.tar.gz')

# %% [markdown]
# Regular grammars
#
# Currently, we have one representation of regular grammars:
#
# 1. [Regular expression](https://en.wikipedia.org/wiki/Regular_expression#Formal_definition)
#
# # Create a regular expression
#
# For example, a regular expression can be created by using function `regex_from_text`
# from Reading and writing grammars.

# %%
regex = cfpq_data.regex_from_text("a (bc|d*)")
# Out:
# [2026-06-05 11:05:10]>INFO>Create regex=(a.(bc|(d)*)) from text='a (bc|d*)'

# %% [markdown]
# # Load regular expression by path
#
# We can load the regular expression along the specified path using function `regex_from_txt`.

# %%
path = cfpq_data.regex_to_txt(regex, "test.txt")
regex_by_path = cfpq_data.regex_from_txt(path)
# Out:
# [2026-06-05 11:05:10]>INFO>Turn regex=(a.(bc|(d)*)) into text='(a (bc|(d)*))'
# [2026-06-05 11:05:10]>INFO>Save regex=(a.(bc|(d)*)) to dest=PosixPath('/home/runner/work/CFPQ_Data/CFPQ_Data/docs/test.txt')
# [2026-06-05 11:05:10]>INFO>Create regex=(a.(bc|(d)*)) from text='(a (bc|(d)*))'
# [2026-06-05 11:05:10]>INFO>Create regex=(a.(bc|(d)*)) from path=PosixPath('/home/runner/work/CFPQ_Data/CFPQ_Data/docs/test.txt')

# %% [markdown]
# Сontext-free grammars
#
# Currently, we have three representations of context-free grammars (CFGs):
#
# 1. [Classic](https://en.wikipedia.org/wiki/Context-free_grammar#Formal_definitions)
#
# 1. [Chomsky Normal Form](https://en.wikipedia.org/wiki/Chomsky_normal_form)
#
# 1. [Recursive State Machine](https://link.springer.com/chapter/10.1007/978-3-030-54832-2_6#Sec2)
#
# # Create a classic context-free grammar
#
# A classic context-free grammar can be created by using function `cfg_from_text`
# from Reading and writing grammars.

# %%
cfg = cfpq_data.cfg_from_text("S -> a S b S | a b")
# Out:
# [2026-06-05 11:05:10]>INFO>Create cfg=<pyformlang.cfg.cfg.CFG object at 0x7f91adf49f50> from text='S -> a S b S | a b', start_symbol=Variable(S)

# %% [markdown]
# # Load context-free grammar by path
#
# We can load the classic context-free grammar along the specified path using function `cfg_from_txt`.

# %%
path = cfpq_data.cfg_to_txt(cfg, "test.txt")
cfg_by_path = cfpq_data.cfg_from_txt(path)
# Out:
# [2026-06-05 11:05:10]>INFO>Turn cfg=<pyformlang.cfg.cfg.CFG object at 0x7f91adf49f50> into text='S -> a S b S\nS -> a b'
# [2026-06-05 11:05:10]>INFO>Save cfg=<pyformlang.cfg.cfg.CFG object at 0x7f91adf49f50> to dest=PosixPath('/home/runner/work/CFPQ_Data/CFPQ_Data/docs/test.txt')
# [2026-06-05 11:05:10]>INFO>Create cfg=<pyformlang.cfg.cfg.CFG object at 0x7f91adf4af90> from text='S -> a S b S\nS -> a b', start_symbol=Variable(S)
# [2026-06-05 11:05:10]>INFO>Create cfg=<pyformlang.cfg.cfg.CFG object at 0x7f91adf4af90> from path=PosixPath('/home/runner/work/CFPQ_Data/CFPQ_Data/docs/test.txt'), start_symbol=Variable(S)

# %% [markdown]
# Generate grammar
#
# We can also generate a grammar for specified template using one of the generators in module Grammar generators.
#
# # Generate a Dyck grammar
#
# For example, let's generate a Dyck grammar of the balanced strings with `a` as an opening parenthesis, `b` as a closing parenthesis, and without the empty string.

# %%
dyck_cfg = cfpq_data.dyck_grammar([("a", "b")], eps=False)
# Out:
# [2026-06-05 11:05:10]>INFO>Create a Dyck cfg=<pyformlang.cfg.cfg.CFG object at 0x7f91adf4b3d0> with types=[('a', 'b')], eps=False

# %% [markdown]
# # Generate a Java Points-to grammar
#
# Also, let's generate a Java Points-to grammar for the field-sensitive analysis of Java programs with field names `f0` and `f1`.

# %%
java_pt_cfg = cfpq_data.java_points_to_grammar(["f0", "f1"])
# Out:
# [2026-06-05 11:05:10]>INFO>Create a Java Points-to cfg=<pyformlang.cfg.cfg.CFG object at 0x7f91adf64a50> with fields=['f0', 'f1']

# %% [markdown]
# Benchmarks
#
# In addition, one of the prepared benchmarks that contains graphs, queries, other input data, and results for
# a particular formal-language-constrained path querying problem can be downloaded.
#
# Currently, we provide the following benchmarks documented on the Benchmarks page:
#
# 1. MS_Reachability
#
# # Load benchmark archive
#
# You can load the archive with the benchmark using function `download_benchmark`.

# %%
ms_reachability_path = cfpq_data.download_benchmark("MS_Reachability")
# Out:
# [2026-06-05 11:05:10]>INFO>Found benchmark with name='MS_Reachability'
# [2026-06-05 11:05:12]>INFO>Load archive benchmark_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/benchmarks/MS_Reachability.tar.gz')
# [2026-06-05 11:05:13]>INFO>Unzip benchmark name='MS_Reachability' to directory benchmark=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/benchmarks/MS_Reachability')
# [2026-06-05 11:05:13]>INFO>Remove archive benchmark_archive=PosixPath('/home/runner/.cache/pypoetry/virtualenvs/cfpq-data-OoGd3T_B-py3.11/lib/python3.11/site-packages/cfpq_data/data/benchmarks/MS_Reachability.tar.gz')

# %% [markdown]
# # MS_Reachability benchmark
#
# MS_Reachability benchmark can be used for the experimental study of the algorithms that solve the multiple-source
# formal-language-constrained reachability problem. This benchmark is described on the MS_Reachability page.
#
# For this benchmark we provide some useful functions from
# Graph utilities.
# For example, the set of source vertices can be saved to the TXT file or it can be loaded from benchmark by using
# functions `multiple_source_from_txt` and
# `multiple_source_to_txt`.

# %%
s = {1, 2, 5, 10}
path = cfpq_data.multiple_source_to_txt(s, "test.txt")
source_vertices = cfpq_data.multiple_source_from_txt(path)
# Out:
# [2026-06-05 11:05:13]>INFO>Save source_vertices={1, 2, 10, 5} to dest=PosixPath('/home/runner/work/CFPQ_Data/CFPQ_Data/docs/test.txt')
# [2026-06-05 11:05:13]>INFO>Load source_vertices={1, 2, 10, 5} from path=PosixPath('/home/runner/work/CFPQ_Data/CFPQ_Data/docs/test.txt')
